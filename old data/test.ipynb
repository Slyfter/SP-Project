# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("data.csv", encoding = "ISO-8859-1", sep=";")

# %%
test = round(df['Goals']*df['90s'])
print(test)
# Out:
# 0       0.0
# 1       2.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 2916    2.0
# 2917    6.0
# 2918    7.0
# 2919    5.0
# 2920    2.0
# Length: 2921, dtype: float64

# %%
# df.insert(2, "RealGoals", round(df['Goals']*df['90s'], True))

df
# Out:
#         Rk             Player  RealGoals Nation   Pos          Squad  \
# 0        1         Max Aarons        0.0    ENG    DF   Norwich City
# 1        2   Yunis Abdelhamid        2.0    MAR    DF          Reims
# 2        3  Salis Abdul Samed        1.1    GHA    MF  Clermont Foot
# 3        4    Laurent Abergel        0.0    FRA    MF        Lorient
# 4        5        Charles Abi        0.0    FRA    FW  Saint-Étienne
# ...    ...                ...        ...    ...   ...            ...
# 2916  2917   Martín Zubimendi        2.0    ESP    MF  Real Sociedad
# 2917  2918   Szymon ?urkowski        5.9    POL    MF         Empoli
# 2918  2919    Martin Ødegaard        7.1    NOR    MF        Arsenal
# 2919  2920        Milan ?uri?        5.1    BIH    FW    Salernitana
# 2920  2921      Filip ?uri?i?        2.0    SRB  MFFW       Sassuolo
#
#                 Comp   Age  Born  MP  ...   Off   Crs  TklW  PKwon  PKcon  \
# ...

# %%
df_roundedRealGoals = df.round({'RealGoals':0})

print(df_roundedRealGoals)
# Out:
#         Rk             Player Nation   Pos          Squad            Comp  \
# 0        1         Max Aarons    ENG    DF   Norwich City  Premier League
# 1        2   Yunis Abdelhamid    MAR    DF          Reims         Ligue 1
# 2        3  Salis Abdul Samed    GHA    MF  Clermont Foot         Ligue 1
# 3        4    Laurent Abergel    FRA    MF        Lorient         Ligue 1
# 4        5        Charles Abi    FRA    FW  Saint-Étienne         Ligue 1
# ...    ...                ...    ...   ...            ...             ...
# 2916  2917   Martín Zubimendi    ESP    MF  Real Sociedad         La Liga
# 2917  2918   Szymon ?urkowski    POL    MF         Empoli         Serie A
# 2918  2919    Martin Ødegaard    NOR    MF        Arsenal  Premier League
# 2919  2920        Milan ?uri?    BIH    FW    Salernitana         Serie A
# 2920  2921      Filip ?uri?i?    SRB  MFFW       Sassuolo         Serie A
#
#        Age  Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  \
# ...

# %%
df.describe()

# %%
df.drop(['Rk','Born','ShoDist','ShoFK','ShoPK','PKatt','PasTotDist','PasTotPrgDist','PasShoCmp','PasShoAtt','PasShoCmp%','PasMedCmp','PasMedCmp%','PasLonCmp','PasLonAtt','PasLonCmp%'],axis=1).head()

# %%
df.groupby(['Comp']).sum()

# %%
df_Bundesliga = df_roundedRealGoals.loc[df['Comp'] == "Bundesliga"]
df_BundesligaGroupedbySquad = df_Bundesliga.groupby(['Squad']).sum()
df_BundesligaGroupedbySquad.sort_values(['RealGoals','Squad'], ascending=False)

# %%
df_byComp = df_roundedRealGoals.groupby(['Comp']).sum()

print(df_byComp)

# %%
df_LaLiga = df.loc[df['Comp'] == "La Liga"]
df_LaLiga.groupby(['Squad']).sum()
